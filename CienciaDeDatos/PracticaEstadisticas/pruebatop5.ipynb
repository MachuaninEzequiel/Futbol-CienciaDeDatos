# %%
import LanusStats as ls

# %%
ls.get_available_pages()
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob'])

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues']

# %%
ls.get_available_season_for_leagues('Fbref' , 'Premier League')
# Out:
# {'id': 9,
#  'slug': 'Premier-League',
#  'seasons': {'2020-2021', '2021-2022', '2022-2023', '2023-2024'}}

# %%
fbref = ls.Fbref()

# %%
fbref.possible_stats
# Out:
# ['stats',
#  'keepers',
#  'keepersadv',
#  'shooting',
#  'passing',
#  'passing_types',
#  'gca',
#  'defense',
#  'possession',
#  'playingtime',
#  'misc']

# %%
fbref.get_teams_season_stats('gca', 'Copa de la Liga', season='2024', save_csv=False, stats_vs=False, change_columns_names=False, add_page_name=False)
# Out:
# Starting to scrape teams data from Fbref...
#                       Squad  # Pl   90s  SCA  SCA90  PassLive  PassDead  TO  \
# 0               Arg Juniors    26  14.0  314  22.43       232        25  18
# 1              Atlé Tucumán    24  14.0  355  25.36       232        41  23
# 2                  Banfield    27  14.0  265  18.93       160        46  16
# 3          Barracas Central    24  14.0  277  19.79       180        31  27
# 4                  Belgrano    33  14.0  272  19.43       177        30  20
# 5              Boca Juniors    29  14.0  275  19.64       189        28  19
# 6          Cen. Córdoba–SdE    31  14.0  215  15.36       138        24  24
# 7            Defensa y Just    30  14.0  318  22.71       216        30  29
# 8         Deportivo Riestra    30  14.0  191  13.64       120        27  13
# 9               Estudiantes    29  14.0  394  28.14       288        27  31
# 10              Gimnasia–LP    26  14.0  336  24.00       230        38  28
# ...

# %%
tabla1 = fbref.get_all_teams_season_stats('Premier League', '2023-2024', save_csv=True, stats_vs=False, change_columns_names=False, add_page_name=False)
# Out:
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...

# %%
tabla1.columns
# Out:
# Index(['Squad', '# Pl', 'Age', 'Poss', 'MP', 'Starts', 'Min', '90s', 'Gls',
#        'Ast',
#        ...
#        'Crs', 'Int', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'Won', 'Lost',
#        'Won%'],
#       dtype='object', length=251)

# %%
tabla1 = tabla1.sort_values(by='Won')
tabla1
# Out:
#               Squad  # Pl   Age  Poss  MP  Starts   Min   90s  Gls  Ast  ...  \
# 12  Manchester City    25  26.6  65.2  38     418  3420  38.0   94   69  ...
# 1       Aston Villa    31  26.9  53.1  38     418  3420  38.0   72   55  ...
# 17        Tottenham    29  25.2  61.6  38     418  3420  38.0   69   58  ...
# 4          Brighton    30  25.9  59.8  38     418  3420  38.0   50   36  ...
# 13   Manchester Utd    31  26.1  50.6  38     418  3420  38.0   57   36  ...
# 6           Chelsea    32  24.2  58.6  38     418  3420  38.0   76   51  ...
# 19           Wolves    27  26.6  48.9  38     418  3420  38.0   47   36  ...
# 14    Newcastle Utd    32  27.2  52.2  38     418  3420  38.0   83   55  ...
# 9            Fulham    25  28.4  50.6  38     418  3420  38.0   54   40  ...
# 0           Arsenal    25  25.0  58.2  38     418  3420  38.0   86   62  ...
# 7    Crystal Palace    26  26.7  42.3  38     418  3420  38.0   56   43  ...
# ...

# %%
tabla2 = fbref.get_teams_season_stats('gca', 'Premier League', season='2023-2024', save_csv=True, stats_vs=False, change_columns_names=False, add_page_name=False)
# Out:
# Starting to scrape teams data from Fbref...
