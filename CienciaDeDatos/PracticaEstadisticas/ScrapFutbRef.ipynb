# %%
import pandas as pd
from matplotlib.offsetbox import (AnnotationBbox, OffsetImage)
import matplotlib.pyplot as plt
from mplsoccer import FontManager, add_image
from PIL import Image

# %%
pagina_entera = pd.read_html('http://fbref.com/es/comps/21/Estadisticas-de-Primera-Division', header=0)

# %%
df = pagina_entera[0]
df
# Out:
#     RL                   Equipo  PJ  PG  PE  PP  GF  GC  DG  Pts  Pts/PJ   xG  \
# 0    1              Racing Club   4   3   1   0  12   4   8   10    2.50  7.8
# 1    2                 Talleres   4   3   1   0   9   3   6   10    2.50  5.1
# 2    3              River Plate   4   3   0   1   9   2   7    9    2.25  6.7
# 3    4              Gimnasia–LP   4   2   1   1   8   4   4    7    1.75  6.2
# 4    5                  Huracán   3   2   1   0   5   2   3    7    2.33  3.7
# 5    6                    Unión   3   2   1   0   4   1   3    7    2.33  4.3
# 6    7  Independiente Rivadavia   3   2   1   0   3   0   3    7    2.33  1.7
# 7    8              Estudiantes   4   2   1   1   5   3   2    7    1.75  5.2
# 8    9                Instituto   4   2   1   1   5   4   1    7    1.75  2.9
# 9   10                 Belgrano   4   2   1   1   7   8  -1    7    1.75  5.6
# 10  11              Newell's OB   3   2   0   1   3   1   2    6    2.00  2.8
# 11  12              Arg Juniors   4   2   0   2   4   6  -2    6    1.50  3.6
# 12  13          Rosario Central   4   1   2   1   6   5   1    5    1.25  4.0
# 13  14          Vélez Sarsfield   4   1   2   1   4   5  -1    5    1.25  3.7
# 14  15                    Lanús   4   1   2   1   4   5  -1    5    1.25  3.2
# 15  16             Atlé Tucumán   4   1   2   1   3   4  -1    5    1.25  4.2
# 16  17                 Platense   4   1   2   1   2   3  -1    5    1.25  4.4
# 17  18             Boca Juniors   4   1   1   2   4   4   0    4    1.00  4.1
# 18  19                Sarmiento   4   1   1   2   3   4  -1    4    1.00  3.2
# 19  20         Barracas Central   3   1   1   1   2   3  -1    4    1.33  2.1
# 20  21            Independiente   4   0   3   1   2   4  -2    3    0.75  2.1
# 21  22        Deportivo Riestra   4   1   0   3   1   5  -4    3    0.75  3.6
# 22  23               Godoy Cruz   3   0   2   1   1   2  -1    2    0.67  3.1
# 23  24           Defensa y Just   4   0   2   2   2   5  -3    2    0.50  2.7
# 24  25              San Lorenzo   3   0   1   2   1   3  -2    1    0.33  2.7
# 25  26                 Banfield   3   0   1   2   1   5  -4    1    0.33  1.9
# 26  27                    Tigre   4   0   1   3   2   9  -7    1    0.25  3.6
# 27  28         Cen. Córdoba–SdE   4   0   0   4   5  13  -8    0    0.00  4.4
#
#      xGA  xGD  xGD/90    Últimos 5  Asistencia  \
# 0    2.6  5.2    1.29  PE PG PG PG         NaN
# 1    3.2  1.9    0.48  PG PG PE PG         NaN
# 2    3.0  3.7    0.92  PG PG PP PG         NaN
# 3    3.3  2.9    0.73  PG PE PG PP         NaN
# 4    2.1  1.6    0.53     PG PE PG         NaN
# 5    2.0  2.2    0.74     PG PE PG         NaN
# 6    2.1 -0.4   -0.15     PG PE PG         NaN
# 7    3.0  2.2    0.54  PG PG PP PE         NaN
# 8    3.6 -0.7   -0.16  PG PE PP PG         NaN
# 9    5.3  0.3    0.07  PE PP PG PG         NaN
# 10   1.4  1.4    0.47     PG PP PG         NaN
# 11   3.2  0.4    0.10  PG PP PG PP         NaN
# 12   4.4 -0.4   -0.09  PP PE PG PE         NaN
# 13   3.7  0.0    0.00  PP PG PE PE         NaN
# 14   3.8 -0.6   -0.16  PP PE PG PE         NaN
# 15   2.8  1.5    0.37  PG PP PE PE         NaN
# 16   2.9  1.5    0.38  PP PE PE PG         NaN
# 17   6.5 -2.4   -0.60  PP PG PE PP         NaN
# 18   3.8 -0.7   -0.17  PP PE PP PG         NaN
# 19   5.1 -3.0   -0.99     PG PE PP         NaN
# 20   4.3 -2.2   -0.54  PP PE PE PE         NaN
# 21   5.3 -1.7   -0.42  PG PP PP PP         NaN
# 22   2.5  0.6    0.20     PP PE PE         NaN
# 23   5.0 -2.3   -0.58  PP PE PP PE         NaN
# 24   1.9  0.8    0.26     PP PE PP         NaN
# 25   4.7 -2.8   -0.95     PP PE PP         NaN
# 26   7.0 -3.3   -0.83  PP PE PP PP         NaN
# 27  10.1 -5.6   -1.41  PP PP PP PP         NaN
#
#                    Máximo Goleador del Equipo                 Portero  Notas
# 0                          Roger Martínez - 3           Gabriel Arias    NaN
# 1                      Bruno Barticciotto - 3           Guido Herrera    NaN
# 2           Miguel Borja, Facundo Colidio - 3           Franco Armani    NaN
# 3                           Matías Abaldo - 3          Nelson Insfrán    NaN
# 4                        Ignacio Pussetto - 3         Hernán Galíndez    NaN
# 5                         Jerónimo Domina - 2          Thiago Cardozo    NaN
# 6      Gastón Gil Romero, Matías Reali... - 1       Gonzalo Marinelli    NaN
# 7   Javier Marcelo Correa, Edwin Cetré... - 1         Matías Mansilla    NaN
# 8                      Santiago Rodriguez - 4            Manuel Roffo    NaN
# 9                             Franco Jara - 3           Nahuel Losada    NaN
# 10  Jerónimo Cacciabue, Armando Méndez... - 1             Lucas Hoyos    NaN
# 11                           Alan Lescano - 2  Diego Matías Rodríguez    NaN
# 12          Marco Ruben, Facundo Mallo... - 1             Jorge Broun    NaN
# 13                         Claudio Aquino - 2         Tomás Marchiori    NaN
# 14                             Walter Bou - 2            Alan Aguerre    NaN
# 15                          Mateo Coronel - 2             Tomás Durso    NaN
# 16                       Mateo Pellegrino - 2            Juan Cozzani    NaN
# 17    Miguel Merentiel, Ignacio Fernández - 2           Sergio Romero    NaN
# 18         Agustín Fontana, Manuel García - 1        Jerónimo Pourtau    NaN
# 19        Alexis Dominguez, Rodrigo Insúa - 1        Sebastián Moyano    NaN
# 20                         Gabriel Ávalos - 1             Rodrigo Rey    NaN
# 21                       Jonathan Herrera - 1            Ignacio Arce    NaN
# 22                          Vicente Poggi - 1          Franco Petroli    NaN
# 23      Nicolás Fernández, Gabriel Alanís - 1    Cristopher Fiermarin    NaN
# 24                      Cristian Ferreira - 1            Gastón Gómez    NaN
# 25                         Milton Giménez - 1     Facundo Sanguinetti    NaN
# 26                         Gonzalo Maroni - 2          Felipe Zenobio    NaN
# 27                           Tomás Molina - 3          Luis Ingolotti    NaN
